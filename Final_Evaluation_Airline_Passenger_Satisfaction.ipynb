# %% [markdown]
# <a href="https://colab.research.google.com/github/vardhman0000/AirlinePassengerSatisfaction/blob/main/Final_Evaluation_Airline_Passenger_Satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Predicting Customer Satisfaction

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Taniya (2210992448)
# ##### **Team Member 2 -** Vardhman Jain (2201992513)
# ##### **Team Member 3 -** Vartika Yadav (2210992515)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Objective:**
# This project aims to predict customer satisfaction in the airline industry through the application of AI/ML techniques. Leveraging survey data, the goal is to provide insights into and predictions of customer sentiment based on various factors.
#
# **Data:**
# The dataset comprises survey responses from airline customers, covering a spectrum of variables including flight experience, customer service, baggage handling, and overall satisfaction ratings.
#
# **Key Analysis:**
#
# *   **Flight Experience Impact:** Investigating how components of the flight experience (e.g., seat comfort, in-flight entertainment) relate to overall customer satisfaction.
#
# *   **Customer Service Examination:** Assessing the impact of customer service interactions on satisfaction ratings, shedding light on the importance of service quality.
#
# *  **On-Time Performance Evaluation:** Analyzing the influence of on-time performance on customer satisfaction, providing insights into punctuality as a key factor.
#
# * **Feature Importance Insights:** Determining the significance of various features in predicting satisfaction, aiding in understanding the drivers behind customer contentment.
#
# **Benefits:**
#
# This project offers a comprehensive understanding of the factors affecting customer satisfaction in the airline industry. By uncovering insights and predicting customer sentiment, airlines can strategically enhance their services, improve overall satisfaction, and bolster their competitive position in the market.
#
# In essence, the project is geared towards utilizing AI/ML to uncover patterns and relationships within survey data, facilitating informed decision-making for the continuous improvement of the customer experience in the airline sector.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vardhman0000/AirlinePassengerSatisfaction.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In the airline industry, the challenge is to predict and understand customer satisfaction effectively. This project tackles this issue by leveraging AI/ML on survey data. The goal is to identify patterns and key factors influencing satisfaction, empowering airlines to proactively enhance their services and improve overall customer experience.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
dftest = pd.read_csv('/content/test.csv')
dftrain = pd.read_csv('/content/train.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dftest.sample(5)
# Out:
#        Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 23593       23593  115401  Female  disloyal Customer   65  Business travel
# 6129         6129  103877    Male     Loyal Customer   40  Personal Travel
# 17841       17841   96604    Male  disloyal Customer   29  Business travel
# 25615       25615  118772  Female     Loyal Customer    9  Personal Travel
# 13373       13373   26013  Female  disloyal Customer   23  Business travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 23593       Eco              362                      1
# 6129        Eco              882                      1
# 17841  Business              972                      2
# 25615       Eco              370                      3
# 13373       Eco              425                      1
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 23593                                  3  ...                       5
# 6129                                   5  ...                       2
# 17841                                  2  ...                       3
# 25615                                  1  ...                       3
# 13373                                  0  ...                       3
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 23593                 1                 4                 3                2
# 6129                  4                 5                 2                5
# 17841                 5                 4                 5                5
# 25615                 4                 3                 2                1
# 13373                 5                 4                 3                1
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 23593                 4            5                          21
# 6129                  2            2                          33
# 17841                 5            3                           2
# 25615                 3            3                           0
# 13373                 1            3                           0
#
#        Arrival Delay in Minutes             satisfaction
# 23593                      20.0  neutral or dissatisfied
# 6129                       21.0  neutral or dissatisfied
# 17841                       NaN  neutral or dissatisfied
# 25615                       3.0  neutral or dissatisfied
# 13373                       0.0  neutral or dissatisfied
#
# [5 rows x 25 columns]

# %%
dftest.head(5)
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# 2                                  0  ...                       2
# 3                                  0  ...                       1
# 4                                  3  ...                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      44.0                satisfied
# 1                       0.0                satisfied
# 2                       0.0  neutral or dissatisfied
# 3                       6.0                satisfied
# 4                      20.0                satisfied
#
# [5 rows x 25 columns]

# %%
dftrain.sample(5)
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 51223       51223  18290    Male     Loyal Customer   70  Business travel
# 8832         8832  84156  Female     Loyal Customer   28  Personal Travel
# 65439       65439  50334  Female     Loyal Customer   50  Business travel
# 70636       70636  56847  Female  disloyal Customer   34  Business travel
# 40196       40196  35191    Male     Loyal Customer   25  Business travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 51223  Business             2754                      3
# 8832   Eco Plus             1355                      2
# 65439  Business              109                      5
# 70636  Business             2454                      3
# 40196  Business             2443                      1
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 51223                                  1  ...                       3
# 8832                                   4  ...                       4
# 65439                                  5  ...                       4
# 70636                                  3  ...                       3
# 40196                                  1  ...                       4
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 51223                 3                 3                 3                4
# 8832                  4                 5                 2                3
# 65439                 4                 4                 5                1
# 70636                 2                 4                 3                2
# 40196                 3                 2                 4                3
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 51223                 3            2                           0
# 8832                  4            4                           0
# 65439                 4            5                           0
# 70636                 3            2                           0
# 40196                 5            4                           0
#
#        Arrival Delay in Minutes             satisfaction
# 51223                      33.0  neutral or dissatisfied
# 8832                        0.0  neutral or dissatisfied
# 65439                      21.0                satisfied
# 70636                       0.0  neutral or dissatisfied
# 40196                       2.0                satisfied
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dftrain.shape
# Out:
# (103904, 25)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dftrain.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
dftrain.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(dftrain.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer :
# 1. There are total 25 Columns and 103904 Rown in dataset.
# 2. No diplicate Values present.
# 3. 310 null values in "Arrival Delay in Minutes" column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dftrain.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Dataset Describe
dftrain.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count           103904.000000  103904.000000   103904.000000    103904.000000
# mean                 2.756901       2.976883        3.202129         3.250375
# std                  1.398929       1.277621        1.329533         1.349509
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         Seat comfort  Inflight entertainment  On-board service  \
# count  103904.000000           103904.000000     103904.000000
# mean        3.439396                3.358158          3.382363
# std         1.319088                1.332991          1.288354
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     103904.000000     103904.000000    103904.000000     103904.000000
# mean           3.351055          3.631833         3.304290          3.640428
# std            1.315605          1.180903         1.265396          1.175663
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count  103904.000000               103904.000000             103594.000000
# mean        3.286351                   14.815618                 15.178678
# std         1.312273                   38.230901                 38.698682
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# id: A unique identifier for each observation or passenger.
#
# Age: The age of the passenger.
#
# Flight Distance: The distance of the flight in miles.
#
# Inflight wifi service: Passenger rating for inflight Wi-Fi service (on a scale, e.g., 1-5).
#
# Departure/Arrival time convenient: Passenger rating for the convenience of departure/arrival times.
#
# Ease of Online booking: Passenger rating for the ease of online booking.
#
# Gate location: Passenger rating for the gate location.
#
# Food and drink: Passenger rating for the quality of food and drink.
#
# Online boarding: Passenger rating for the online boarding process.
#
# Seat comfort: Passenger rating for the comfort of the seats.
#
# Inflight entertainment: Passenger rating for the quality of inflight entertainment.
#
# On-board service: Passenger rating for the overall on-board service.
#
# Leg room service: Passenger rating for the legroom service.
#
# Baggage handling: Passenger rating for the baggage handling.
#
# Checkin service: Passenger rating for the check-in service.
#
# Inflight service: Passenger rating for the overall inflight service.
#
# Cleanliness: Passenger rating for the cleanliness of the aircraft.
#
# Departure Delay in Minutes: The delay in minutes for the departure of the flight.
#
# Arrival Delay in Minutes: The delay in minutes for the arrival of the flight.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
dftrain.nunique().reset_index()
# Out:
#                                 index       0
# 0                          Unnamed: 0  103904
# 1                                  id  103904
# 2                              Gender       2
# 3                       Customer Type       2
# 4                                 Age      75
# 5                      Type of Travel       2
# 6                               Class       3
# 7                     Flight Distance    3802
# 8               Inflight wifi service       6
# 9   Departure/Arrival time convenient       6
# 10             Ease of Online booking       6
# 11                      Gate location       6
# 12                     Food and drink       6
# 13                    Online boarding       6
# 14                       Seat comfort       6
# 15             Inflight entertainment       6
# 16                   On-board service       6
# 17                   Leg room service       6
# 18                   Baggage handling       5
# 19                    Checkin service       6
# 20                   Inflight service       6
# 21                        Cleanliness       6
# 22         Departure Delay in Minutes     446
# 23           Arrival Delay in Minutes     455
# 24                       satisfaction       2

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
median_val = dftrain['Arrival Delay in Minutes'].median()
# Filling missing values with median as distribution of arrival delay was heavily skewed
dftrain['Arrival Delay in Minutes'] = dftrain['Arrival Delay in Minutes'].fillna(median_val)

# %%
dftrain.drop(columns=['Unnamed: 0'],axis = 1, inplace=True)
dftrain.sample()
# Out:
#            id Gender      Customer Type  Age   Type of Travel Class  \
# 95957  108859   Male  disloyal Customer   22  Business travel   Eco
#
#        Flight Distance  Inflight wifi service  \
# 95957              943                      1
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 95957                                  1                       1  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 95957                       1                 2                 4
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 95957                 4                4                 4            1
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  \
# 95957                          13                      42.0
#
#                   satisfaction
# 95957  neutral or dissatisfied
#
# [1 rows x 24 columns]

# %%
dftrain['satisfaction'] = dftrain['satisfaction'].map({
    'satisfied' : 1,
    'neutral or dissatisfied' : 0
})
dftrain.sample(10)
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 50228    26410  Female     Loyal Customer   37  Business travel  Business
# 95464    91666    Male     Loyal Customer   40  Business travel  Eco Plus
# 99007   102498    Male     Loyal Customer   41  Personal Travel       Eco
# 45056    38888    Male  disloyal Customer   39  Business travel       Eco
# 43653    40799  Female     Loyal Customer   39  Business travel  Business
# 45494     6604    Male     Loyal Customer   51  Personal Travel       Eco
# 38003    10575  Female     Loyal Customer   54  Business travel  Business
# 47123     8496    Male  disloyal Customer   10  Business travel       Eco
# 103075   96597    Male     Loyal Customer   24  Personal Travel       Eco
# 29899    50625  Female     Loyal Customer   49  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 50228              1249                      3
# 95464               799                      5
# 99007               258                      3
# 45056               621                      4
# 43653              1926                      3
# 45494               473                      2
# 38003              2953                      4
# 47123               862                      1
# 103075              861                      3
# 29899                86                      2
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 50228                                   2                       2  ...
# 95464                                   3                       3  ...
# 99007                                   1                       3  ...
# 45056                                   0                       4  ...
# 43653                                   2                       2  ...
# 45494                                   4                       2  ...
# 38003                                   4                       4  ...
# 47123                                   1                       1  ...
# 103075                                  4                       3  ...
# 29899                                   2                       2  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 50228                        3                 3                 3
# 95464                        5                 1                 4
# 99007                        3                 4                 1
# 45056                        2                 3                 3
# 43653                        3                 3                 3
# 45494                        3                 3                 4
# 38003                        5                 5                 5
# 47123                        1                 2                 3
# 103075                       5                 4                 5
# 29899                        2                 2                 2
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 50228                  3                1                 3            1
# 95464                  1                3                 4            5
# 99007                  4                1                 3            3
# 45056                  5                1                 2            2
# 43653                  3                1                 3            2
# 45494                  1                1                 5            3
# 38003                  5                3                 5            4
# 47123                  3                4                 4            1
# 103075                 5                3                 4            5
# 29899                  2                3                 2            4
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 50228                            0                       0.0             0
# 95464                            0                       0.0             1
# 99007                           22                       8.0             0
# 45056                            0                      18.0             0
# 43653                            0                       2.0             0
# 45494                            3                       4.0             0
# 38003                            0                       0.0             1
# 47123                            0                       0.0             0
# 103075                           0                       3.0             0
# 29899                            0                       0.0             0
#
# [10 rows x 24 columns]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer :
# 1. Replaced Null Values with median values
# 2. Dropped "Unnamed : 0" column because it holds same values as of "id" column

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ####Chart - 1

# %%
#Distribution of Travel Classes
class_counts = dftrain['Class'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', colors=['#66b3ff', '#99ff99', '#ffcc99'], startangle=90)
plt.title('Distribution of Travel Classes')
plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are effective for displaying the proportional distribution of categories within a whole, providing a quick visual summary of relative proportions in a concise manner.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We find that most passengers travel via **Business Class** while the least number of passengers travel via **Economy Plus**.

# %% [markdown]
# ##### Will the gained insights help creating a positive business impact?

# %% [markdown]
# This information can help in optimizing seat allocation, pricing strategies, and overall resource management to meet customer preferences, potentially enhancing revenue and customer satisfaction.

# %% [markdown]
# ####Chart-2

# %%
import matplotlib.pyplot as plt
sns.kdeplot(data=dftrain, x="Age", fill=True)
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# Histograms are simple, clear, and allow easy comparison of age frequencies, making them effective for visualizing the distribution of passenger ages.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the age group with the most passengers is between 50 and 60 years old. There is a sharp decline in the number of passengers after the age of 60.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impacts:**
#
# * **Targeted Marketing:** Understanding the dominant age group allows airlines to tailor marketing messages and promotions to resonate better (comfort, reliable schedules, etc.). This could boost passenger numbers and revenue.
# * **Amenities and Services:** Airlines can cater inflight services and entertainment options to appeal to an older audience, potentially improving customer satisfaction and loyalty.
#
# **Negative Impacts:**
#
# * **Missed Growth Opportunities:** If airlines excessively focus on older customers, they may miss out on developing strategies to attract younger generations. This could limit long-term growth prospects.
# * **Perception as Outdated:** An airline perceived to cater primarily to an older demographic risks becoming less appealing to younger travelers looking for a more modern or dynamic experience.

# %% [markdown]
# #### Chart - 3

# %%
#How does customer satisfaction vary between different genders?
plt.figure(figsize=(10, 6))
sns.countplot(x='satisfaction', hue='Gender', data=dftrain, palette='pastel')


plt.title('Customer Satisfaction by Gender')
plt.xlabel('Satisfaction Level')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is ideal for comparing customer satisfaction levels across genders because both variables are categorical. The simplicity and effectiveness of a bar plot make it a suitable choice for illustrating how satisfaction varies between different genders.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that there are more male customers than female customers who are not satisfied with their experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, understanding and acting upon the insights gained can positively impact targeted marketing, customer experience, product adjustments, employee training, and overall brand reputation and loyalty.

# %% [markdown]
# #### Chart - 4

# %%
#Are there differences in satisfaction levels between loyal and disloyal customers?
plt.figure(figsize=(12, 8))
sns.boxplot(x='Customer Type', y='satisfaction', data=dftrain, hue='Gender',palette='flare')

# Add labels and title
plt.title('Customer Satisfaction by Customer Type')
plt.xlabel('Customer Type')
plt.ylabel('Satisfaction Level')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is advantageous for comparing satisfaction levels between customer types because it provides a clear overview of the distribution, facilitates comparison of central tendency, identifies outliers, and offers a compact representation of data variability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a higher percentage of customers are satisfied than dissatisfied, and that a higher percentage of loyal customers are satisfied than disloyal customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** The analysis reveals higher satisfaction among **loyal customers**, the airline can tailor services and marketing strategies to enhance loyalty and attract similar customers, potentially leading to increased revenue.
#
# **Negative Impact:** The findings indicate dissatisfaction within **disloyal customers**, the airline may face negative consequences, including customer attrition, damaged reputation, and reduced profitability. Addressing identified issues promptly is crucial to mitigate negative impacts.

# %%
import matplotlib.pyplot as plt
sns.kdeplot(data=dftrain, x="Age", fill=True)
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# #### Chart - 5

# %%
#Age Distribution of Passengers
plt.figure(figsize=(10, 6))
sns.histplot(dftrain['Age'], bins=30, kde=False, color='skyblue')

plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms are simple, clear, and allow easy comparison of age frequencies, making them effective for visualizing the distribution of passenger ages.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the age group with the most passengers is between **50 and 60 years old.** There is a sharp decline in the number of passengers after the age of 60.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impacts:**
#
# * **Targeted Marketing:** Understanding the dominant age group allows airlines to tailor marketing messages and promotions to resonate better (comfort, reliable schedules, etc.). This could boost passenger numbers and revenue.
# * **Amenities and Services:** Airlines can cater inflight services and entertainment options to appeal to an older audience, potentially improving customer satisfaction and loyalty.
#
# **Negative Impacts:**
#
# * **Missed Growth Opportunities:** If airlines excessively focus on older customers, they may miss out on developing strategies to attract younger generations. This could limit long-term growth prospects.
# * **Perception as Outdated:** An airline perceived to cater primarily to an older demographic risks becoming less appealing to younger travelers looking for a more modern or dynamic experience.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 4 visualization code
plt.figure(figsize=(12, 8))

sns.lineplot(x='Departure Delay in Minutes', y='Inflight wifi service', data=dftrain, color='skyblue', label='Inflight wifi')
sns.lineplot(x='Departure Delay in Minutes', y='Seat comfort', data=dftrain, color='orange', label='Seat comfort')

# Add labels and title
plt.title('Effect of Departure Delays on Service Ratings')
plt.xlabel('Departure Delay in Minutes')
plt.ylabel('Service Ratings')

# Show the plot
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots were chosen for their ability to visualize individual data points and assess the correlation between departure delays and service ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight found from the chart is that departure delays have a negative impact on service ratings. As the departure delay increases, the service rating score goes down. This suggests that passengers are less satisfied with the airline's service when their flights are delayed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can lead to positive business growth by prioritizing customer experience and satisfaction. By addressing the negative impact of delays, the airline can build stronger customer loyalty, improve its brand image, and ultimately achieve sustainable growth.

# %% [markdown]
# #### Chart - 7

# %%
#What is the relationship between departure delays and overall satisfaction, considering different classes of travel?

plt.figure(figsize=(12, 8))
sns.barplot(x='Departure Delay in Minutes', y='satisfaction', hue='Class', data=dftrain, palette='viridis', alpha=0.7)

# Add labels and title
plt.title('Relationship between Departure Delays and Overall Satisfaction by Travel Class')
plt.xlabel('Departure Delay in Minutes')
plt.ylabel('Overall Satisfaction')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is not the ideal choice for visualizing the relationship between two continuous variables like departure delays and overall satisfaction, especially when considering different classes of travel. Bar charts are typically used for comparing categorical data or showing the distribution of a single variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Overall, passengers in all travel classes tend to be more satisfied with their experience when there are fewer departure delays. This is because the larger sections of the bars are in the "satisfied" category when the departure delay is low (0 minutes).
#
# * Business Class passengers appear to have the highest overall satisfaction across all departure delay durations. The "satisfied" section of the bar is consistently larger for Business Class compared to Economy and Economy Plus Classes.
#
# * Economy Class passengers seem to have the lowest overall satisfaction across all departure delay durations. The "satisfied" section of the bar is consistently smaller for Economy Class compared to the other two classes.
#
# As departure delays increase, the proportion of dissatisfied passengers increases for all travel classes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive:** The airline can focus on reducing delays, which benefits all classes and directly addresses a major factor impacting overall satisfaction. This leads to happier customers, potentially resulting in increased loyalty and revenue.
#
# **Negative:** If the airline misinterprets the data and solely focuses on improving Business Class satisfaction, they might neglect the larger, dissatisfied Economy Class segment. This could lead to further decline in their satisfaction, potentially causing customer churn and negative brand perception, impacting growth.

# %% [markdown]
# #### Chart - 8

# %%
# What is the distribution of age for satisfied and dissatisfied passengers?
plt.figure(figsize=(10, 6))
sns.violinplot(x='satisfaction', y='Age', data=dftrain, palette='pastel', inner='quartile')

# Add labels and title
plt.title('Distribution of Age for Satisfied and Dissatisfied Passengers')
plt.xlabel('Satisfaction')
plt.ylabel('Age')
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-25-e7d08417a067>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='satisfaction', y='Age', data=dftrain, palette='pastel', inner='quartile')
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Violin plots are chosen for their ability to display the distribution of age for satisfied and dissatisfied passengers, providing insights into density, central tendency, and potential subgroups in a visually appealing manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Younger individuals (likely teens and young adults) tend to report higher satisfaction.
# * Satisfaction dips in middle age (around 40-50 years old).
# * Satisfaction then rises again in older age groups (seniors).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:**
# The airline can tailor marketing and services to specific age groups based on their satisfaction levels, potentially attracting new customers and increasing overall satisfaction and loyalty.
# * **Negative Impact:**
# Oversimplification of the data by solely focusing on age could lead to neglecting other customer segments with varying satisfaction levels, potentially resulting in dissatisfied customers and lost growth opportunities

# %% [markdown]
# #### Chart - 9

# %%
#Is there a correlation between the ease of online booking and satisfaction levels among various age groups?

plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='satisfaction', hue='Ease of Online booking', data=dftrain, palette='viridis')

# Add labels and title
plt.title('Grouped Bar Chart: Ease of Online Booking, Satisfaction, and Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Satisfaction')

# Show the legend
plt.legend(title='Ease of Online Booking',loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart is effective for comparing satisfaction levels across different age groups and ease of online booking categories, providing a clear visual representation of interactions and patterns. Its simplicity makes it accessible and suitable for categorical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Easier online booking leads to higher customer satisfaction.
# * Customers who are dissatisfied tend to find booking flights online more difficult.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
# Focusing on improving the online booking system's ease of use can boost customer satisfaction, leading to higher loyalty and potentially increased revenue.

# %% [markdown]
# #### Chart - 10

# %%
#How does the average flight distance vary between male and female passengers?

plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='Flight Distance', data=dftrain, palette='viridis', ci=None)

# Add labels and title
plt.title('Average Flight Distance Across Gender')
plt.xlabel('Gender')
plt.ylabel('Average Flight Distance')

# Show the plot
plt.show()
# Out:
# <ipython-input-27-4feb74a87727>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Gender', y='Flight Distance', data=dftrain, palette='viridis', ci=None)
# <ipython-input-27-4feb74a87727>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Flight Distance', data=dftrain, palette='viridis', ci=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are good for comparing average flight distances between male and female passengers because they offer a clear, simple, and visually accessible way to compare a single numerical variable (flight distance) across two categories (gender).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average flight distance appears to be higher for male passengers compared to female passengers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:**
# Understanding gender differences in travel patterns can help airlines tailor marketing and services to specific needs. This could lead to increased customer satisfaction and loyalty.
#
# * **Negative Impact:**
# Overly relying on gender stereotypes could lead to exclusion and missed business opportunities. The observed trend might not apply to all individuals within each gender group.

# %% [markdown]
# #### Chart - 11

# %%
#Which onboard services (e.g., food and drink, legroom, cleanliness) are most strongly associated with high customer satisfaction?



# Select relevant columns
onboard_services = dftrain[['Food and drink', 'Leg room service', 'Cleanliness', 'satisfaction']]

# Calculate the correlation matrix
correlation_matrix = onboard_services.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Add title
plt.title('Correlation between Onboard Services and Satisfaction')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is efficient for quickly identifying the strength and direction of correlations between various onboard services and customer satisfaction levels through color-coded visual representation, offering a concise overview of the relationships in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Onboard services are perceived as more important than food and drink by a significant margin. The bar for onboard services is considerably higher than the bar for food and drink.
#
# * There is a neutral perception towards both onboard services and food and drink. This is because the bars for both categories are positioned in the middle of the scale, indicating neither strong satisfaction nor dissatisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
# Focusing on improving onboard services, based on their higher perceived importance, can potentially lead to increased customer satisfaction and loyalty. This could translate to higher revenue from repeat bookings and positive word-of-mouth recommendations.
#
# **Negative Impact:**
# Neglecting food and drink offerings, despite a neutral perception, could still be a missed opportunity to differentiate the airline from competitors and potentially lead to lost business opportunities if other airlines offer better food and drink options.

# %% [markdown]
# #### Chart - 12

# %%
#Count of passengers across various columns
fig, axes = plt.subplots(3, 4, figsize = (20, 12))
sns.countplot(x = 'Gender', data = dftrain, palette= 'winter', ax = axes[0, 0],hue='Gender');
sns.countplot(x = 'Customer Type', data = dftrain, palette= 'winter', ax = axes[0, 1],hue='Customer Type');
sns.countplot(x = 'Type of Travel', data = dftrain, palette= 'winter', ax = axes[0, 2],hue='Type of Travel');
sns.countplot(x = 'Seat comfort', data = dftrain, palette= 'winter', ax = axes[0, 3],hue='Seat comfort',legend=False);
sns.countplot(x = 'Class', data = dftrain, palette= 'winter', ax = axes[1, 0],hue='Class');
sns.countplot(x = 'Inflight wifi service', data = dftrain, palette= 'winter', ax = axes[1, 1],hue='Inflight wifi service',legend=False);
sns.countplot(x = 'Departure/Arrival time convenient', data = dftrain, palette= 'winter', ax = axes[1, 2],hue='Departure/Arrival time convenient',legend=False);
sns.countplot(x = 'On-board service', data = dftrain, palette= 'winter', ax = axes[1, 3],hue='On-board service',legend=False);
sns.countplot(x = 'Ease of Online booking', data = dftrain, palette= 'winter', ax = axes[2, 0],hue='Ease of Online booking',legend=False);
sns.countplot(x = 'Food and drink', data = dftrain, palette= 'winter', ax = axes[2, 1],hue='Food and drink',legend=False);
sns.countplot(x = 'Inflight service', data = dftrain, palette= 'winter', ax = axes[2, 2],hue='Inflight service',legend=False);
sns.countplot(x = 'Cleanliness', data = dftrain, palette= 'winter', ax = axes[2, 3],hue='Cleanliness',legend=False);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Count plots are effective in displaying the distribution of categorical variables by counting the occurrences of each category. This allows quick insight into the frequency or prevalence of different categories within a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Food and Drink facilities have almost equal number of 2, 3, 4 and 5 ratings.
# * Wifi and Ease of Online Booking have recieved 2 out of 5 majority of the times

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  The airline can use this information to prioritize improvements in these specific areas, enhancing customer satisfaction, and staying competitive in the market.

# %% [markdown]
# #### Chart - 13

# %%
# plt.figure(figsize=(14, 6))
# sns.heatmap(dftrain.corr(), annot=True, fmt='.2f', linewidths=0.8, cmap="YlGnBu")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-947a77da15ef> in <cell line: 11>()
#       9
#      10 plt.figure(figsize=(14, 6))
# ---> 11 sns.heatmap(dftrain.corr(), annot=True, fmt='.2f', linewidths=0.8, cmap="YlGnBu")
#      12 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1730                 arr.flags.writeable = False
#    1731         else:
# -> 1732             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733             # The underlying data was copied within _interleave, so no need
#    1734             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1792             else:
#    1793                 arr = blk.get_values(dtype)
# -> 1794             result[rl.indexer] = arr
#    1795             itemmask[rl.indexer] = 1
#    1796
#
# ValueError: could not convert string to float: 'Male'

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps provide a concise and efficient way to visually represent the correlation matrix, allowing quick identification of relationships and patterns in large datasets.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Departure Delay and Arrival delay are heavily correlated with each other, therefore one of them should be dropped.

# %% [markdown]
# #### Chart - 14

# %%
#Relation between Delay in departure and Delay in arrival
plt.figure(figsize = (10, 6))
sns.scatterplot(x = 'Departure Delay in Minutes', y = 'Arrival Delay in Minutes', data = dftrain, color = 'teal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots offer a concise visual representation to observe relationships and patterns between two variables, aiding in the identification of trends, correlations, or outliers in a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Flights that are delayed on departure are also somewhat more likely to be delayed on arrival, but there are also many flights that are delayed on departure but arrive on time, and vice versa.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive impacts:**
#
# * The airline company can use the information to identify flights that are more likely to be delayed on arrival, which could allow them to take steps to mitigate those delays, such as pre-positioning maintenance crews at arrival airports.
# * The airline company can use the information to track their progress over time in reducing delays.
#
# **Negative impacts:**
#
# * The information in the graph does not tell the airline company anything about the cause of the delays. Therefore, it is difficult to use the information to take specific steps to reduce delays.
# * The correlation between departure delay and arrival delay is weak, so the information may not be very useful for predicting which specific flights will be delayed on arrival.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

numerical_columns = dftrain[['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']]

# Create a pair plot
sns.pairplot(numerical_columns)
plt.suptitle('Pair Plot of Numerical Columns', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plots are commonly used in exploratory data analysis to identify trends, clusters, or potential outliers in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * There is a weak positive correlation between departure delay and arrival delay. This means that flights that are delayed on departure are somewhat more likely to also be delayed on arrival, but there are many exceptions.
#
# * There is no clear correlation between flight distance and arrival delay. This suggests that longer flights are not necessarily more likely to be delayed than shorter flights.

# %% [markdown]
# ## ***Data Preprocessing***

# %% [markdown]
# Importing the dataset:

# %%
train_df = pd.read_csv("/content/train.csv")
test_df = pd.read_csv("/content/test.csv")

train_df.dropna(inplace=True)
test_df.dropna(inplace=True)

train_df = train_df.iloc[:1500,::]
test_df = test_df.iloc[:300,::]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1500 entries, 0 to 1501
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         1500 non-null   int64
#  1   id                                 1500 non-null   int64
#  2   Gender                             1500 non-null   object
#  3   Customer Type                      1500 non-null   object
#  4   Age                                1500 non-null   int64
#  5   Type of Travel                     1500 non-null   object
#  6   Class                              1500 non-null   object
#  7   Flight Distance                    1500 non-null   int64
#  8   Inflight wifi service              1500 non-null   int64
#  9   Departure/Arrival time convenient  1500 non-null   int64
#  10  Ease of Online booking             1500 non-null   int64
#  11  Gate location                      1500 non-null   int64
#  12  Food and drink                     1500 non-null   int64
#  13  Online boarding                    1500 non-null   int64
#  14  Seat comfort                       1500 non-null   int64
#  15  Inflight entertainment             1500 non-null   int64
#  16  On-board service                   1500 non-null   int64
#  17  Leg room service                   1500 non-null   int64
#  18  Baggage handling                   1500 non-null   int64
#  19  Checkin service                    1500 non-null   int64
#  20  Inflight service                   1500 non-null   int64
#  21  Cleanliness                        1500 non-null   int64
#  22  Departure Delay in Minutes         1500 non-null   int64
#  23  Arrival Delay in Minutes           1500 non-null   float64
#  24  satisfaction                       1500 non-null   object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 304.7+ KB

# %% [markdown]
# ###1. Handling Missing Values

# %%
# First of all, we start by dropping the variables hello and enes, which does not work for us, in our data.

train_df.drop(["Unnamed: 0","id"],axis=1, inplace=True)

# Finally, we convert our target variable "satisfaction" to 0 and 1 (binary) values in order to use it in machine learning and simple data analysis.

train_df.satisfaction = [1 if x == "satisfied" else 0 for x in train_df.satisfaction]

train_df.head()
# Out:
# <ipython-input-35-4687a817c5ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(["Unnamed: 0","id"],axis=1, inplace=True)
# <ipython-input-35-4687a817c5ab>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.satisfaction = [1 if x == "satisfied" else 0 for x in train_df.satisfaction]
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
train_df.columns = [x.split()[0] + "_" + x.split()[1] + "_" + x.split()[2] + "_" + x.split()[3] if len(x.split()) > 3 else x for x in train_df.columns]
train_df.columns = [x.split()[0] + "_" + x.split()[1] + "_" + x.split()[2] if len(x.split()) > 2 else x for x in train_df.columns]
train_df.columns = [x.split()[0] + "_" + x.split()[1] if len(x.split()) > 1 else x for x in train_df.columns]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1500 entries, 0 to 1501
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             1500 non-null   object
#  1   Customer_Type                      1500 non-null   object
#  2   Age                                1500 non-null   int64
#  3   Type_of_Travel                     1500 non-null   object
#  4   Class                              1500 non-null   object
#  5   Flight_Distance                    1500 non-null   int64
#  6   Inflight_wifi_service              1500 non-null   int64
#  7   Departure/Arrival_time_convenient  1500 non-null   int64
#  8   Ease_of_Online_booking             1500 non-null   int64
#  9   Gate_location                      1500 non-null   int64
#  10  Food_and_drink                     1500 non-null   int64
#  11  Online_boarding                    1500 non-null   int64
#  12  Seat_comfort                       1500 non-null   int64
#  13  Inflight_entertainment             1500 non-null   int64
#  14  On-board_service                   1500 non-null   int64
#  15  Leg_room_service                   1500 non-null   int64
#  16  Baggage_handling                   1500 non-null   int64
#  17  Checkin_service                    1500 non-null   int64
#  18  Inflight_service                   1500 non-null   int64
#  19  Cleanliness                        1500 non-null   int64
#  20  Departure_Delay_in_Minutes         1500 non-null   int64
#  21  Arrival_Delay_in_Minutes           1500 non-null   float64
#  22  satisfaction                       1500 non-null   int64
# dtypes: float64(1), int64(18), object(4)
# memory usage: 281.2+ KB

# %%
dftest.drop(["Unnamed: 0","id"],axis=1, inplace=True)

dftest.columns = [x.split()[0] + "_" + x.split()[1] + "_" + x.split()[2] + "_" + x.split()[3] if len(x.split()) > 3 else x for x in dftest.columns]
dftest.columns = [x.split()[0] + "_" + x.split()[1] + "_" + x.split()[2] if len(x.split()) > 2 else x for x in dftest.columns]
dftest.columns = [x.split()[0] + "_" + x.split()[1] if len(x.split()) > 1 else x for x in dftest.columns]

# %%
dftest.satisfaction = [1 if x == "satisfied" else 0 for x in dftest.satisfaction]

dftest.head()
# Out:
#    Gender      Customer_Type  Age   Type_of_Travel     Class  Flight_Distance  \
# 0  Female     Loyal Customer   52  Business travel       Eco              160
# 1  Female     Loyal Customer   36  Business travel  Business             2863
# 2    Male  disloyal Customer   20  Business travel       Eco              192
# 3    Male     Loyal Customer   44  Business travel  Business             3377
# 4  Female     Loyal Customer   49  Business travel       Eco             1182
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# 0                       3              4  ...                       5
# 1                       3              1  ...                       4
# 2                       2              4  ...                       2
# 3                       0              2  ...                       1
# 4                       4              3  ...                       2
#
#    On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival_Delay_in_Minutes  satisfaction
# 0                      44.0             1
# 1                       0.0             1
# 2                       0.0             0
# 3                       6.0             1
# 4                      20.0             1
#
# [5 rows x 23 columns]

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Dropping columns is another approach to handling missing values, but it's more of a preprocessing step rather than an imputation technique. If those columns contain irrelevant or redundant information, dropping them can be a reasonable choice.

# %% [markdown]
# We convert the "Gender","Type_of_Travel","Customer Type" variables in our data into numerical data types in order to use them in our logistic regression model.

# %% [markdown]
# ### 2. Handling Outliers

# %%
from collections import Counter

def detect_outliers(df,features):
    outlier_indices = []

    for c in features:
        # 1st quartile
        Q1 = np.percentile(df[c],25)
        # 3rd quartile
        Q3 = np.percentile(df[c],75)
        # IQR
        IQR = Q3 - Q1
        # Outlier step
        outlier_step = IQR * 1.5
        # detect outlier and their indeces
        outlier_list_col = df[(df[c] < Q1 - outlier_step) | (df[c] > Q3 + outlier_step)].index
        # store indeces
        outlier_indices.extend(outlier_list_col)

    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i, v in outlier_indices.items() if v > 2)

    return multiple_outliers

# %%
train_df.loc[detect_outliers(train_df,["Age", "Flight_Distance", "Inflight_wifi_service", "Departure/Arrival_time_convenient", "Ease_of_Online_booking", "Gate_location", "Food_and_drink", "Online_boarding", "Seat_comfort", "Inflight_entertainment", "On-board_service", "Leg_room_service", "Checkin_service", "Inflight_service", "Cleanliness", "Departure_Delay_in_Minutes", "Arrival_Delay_in_Minutes"])]
# Out:
#       Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 80      Male     Loyal Customer   26  Business travel  Business
# 717     Male     Loyal Customer   32  Business travel  Business
# 1061    Male     Loyal Customer   57  Business travel  Business
# 71      Male     Loyal Customer   30  Business travel  Eco Plus
# 305   Female  disloyal Customer   62  Business travel       Eco
# 424   Female     Loyal Customer   56  Personal Travel       Eco
# 429   Female     Loyal Customer   41  Business travel  Business
# 624   Female  disloyal Customer   28  Business travel       Eco
# 671     Male     Loyal Customer   35  Business travel  Business
# 805   Female     Loyal Customer   58  Business travel  Eco Plus
# 868     Male     Loyal Customer   26  Business travel       Eco
# 919   Female     Loyal Customer   33  Personal Travel       Eco
# 961     Male     Loyal Customer   38  Business travel  Business
# 1139    Male     Loyal Customer   34  Business travel  Business
# 1192    Male     Loyal Customer   43  Personal Travel  Business
# 1218  Female     Loyal Customer   20  Personal Travel       Eco
# 1222    Male     Loyal Customer   16  Personal Travel       Eco
# 1225    Male     Loyal Customer   66  Business travel  Eco Plus
# 1246  Female     Loyal Customer   22  Business travel  Business
# 1351  Female  disloyal Customer   36  Business travel       Eco
# 1358  Female     Loyal Customer   51  Business travel  Business
# 1395    Male     Loyal Customer   15  Business travel  Business
# 1402    Male     Loyal Customer   41  Personal Travel       Eco
# 1418  Female     Loyal Customer   31  Business travel  Business
#
#       Flight_Distance  Inflight_wifi_service  \
# 80               3960                      1
# 717              3802                      0
# 1061             3902                      1
# 71                205                      3
# 305               255                      3
# 424               236                      3
# 429               209                      4
# 624               160                      4
# 671               589                      2
# 805               229                      4
# 868              1085                      4
# 919               546                      3
# 961              1642                      1
# 1139             3162                      1
# 1192             2521                      5
# 1218              926                      3
# 1222              945                      3
# 1225              192                      2
# 1246             3152                      1
# 1351              391                      2
# 1358             2133                      2
# 1395              853                      2
# 1402              944                      3
# 1418              642                      3
#
#       Departure/Arrival_time_convenient  Ease_of_Online_booking  \
# 80                                    1                       1
# 717                                   0                       0
# 1061                                  1                       1
# 71                                    2                       2
# 305                                   3                       2
# 424                                   3                       3
# 429                                   4                       4
# 624                                   2                       4
# 671                                   4                       1
# 805                                   5                       5
# 868                                   5                       2
# 919                                   4                       4
# 961                                   3                       3
# 1139                                  1                       4
# 1192                                  2                       5
# 1218                                  5                       3
# 1222                                  1                       3
# 1225                                  2                       4
# 1246                                  4                       4
# 1351                                  1                       2
# 1358                                  5                       5
# 1395                                  4                       4
# 1402                                  5                       3
# 1418                                  3                       3
#
#       Gate_location  ...  Inflight_entertainment  On-board_service  \
# 80                1  ...                       4                 4
# 717               1  ...                       5                 3
# 1061              1  ...                       5                 5
# 71                2  ...                       3                 2
# 305               2  ...                       2                 1
# 424               3  ...                       4                 4
# 429               4  ...                       2                 2
# 624               4  ...                       1                 2
# 671               4  ...                       2                 2
# 805               5  ...                       4                 4
# 868               5  ...                       4                 3
# 919               4  ...                       5                 1
# 961               3  ...                       4                 4
# 1139              1  ...                       5                 5
# 1192              2  ...                       3                 4
# 1218              4  ...                       5                 4
# 1222              3  ...                       2                 3
# 1225              2  ...                       2                 2
# 1246              4  ...                       1                 4
# 1351              4  ...                       1                 1
# 1358              5  ...                       2                 2
# 1395              4  ...                       2                 4
# 1402              5  ...                       1                 4
# 1418              3  ...                       4                 1
#
#       Leg_room_service  Baggage_handling  Checkin_service  Inflight_service  \
# 80                   2                 5                4                 4
# 717                  2                 5                4                 5
# 1061                 5                 5                4                 5
# 71                   5                 1                1                 2
# 305                  5                 3                1                 3
# 424                  3                 4                1                 4
# 429                  2                 4                1                 2
# 624                  4                 3                1                 4
# 671                  2                 2                1                 2
# 805                  4                 4                1                 4
# 868                  5                 4                1                 3
# 919                  5                 3                1                 5
# 961                  2                 2                1                 2
# 1139                 5                 5                1                 5
# 1192                 1                 3                1                 1
# 1218                 5                 5                1                 5
# 1222                 1                 3                1                 4
# 1225                 5                 3                1                 3
# 1246                 3                 3                1                 3
# 1351                 3                 4                1                 3
# 1358                 2                 2                1                 2
# 1395                 1                 3                1                 4
# 1402                 5                 3                1                 1
# 1418                 5                 3                1                 5
#
#       Cleanliness  Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  \
# 80              4                          45                      48.0
# 717             5                          90                      86.0
# 1061            3                          55                      53.0
# 71              3                          64                      49.0
# 305             2                         113                     107.0
# 424             5                          57                      52.0
# 429             2                          95                     100.0
# 624             1                          52                      44.0
# 671             3                          44                      46.0
# 805             4                          63                      75.0
# 868             4                          94                      86.0
# 919             5                          80                      76.0
# 961             1                         156                     155.0
# 1139            2                          80                      73.0
# 1192            1                          60                      51.0
# 1218            1                         136                     124.0
# 1222            2                          46                      59.0
# 1225            2                          53                      42.0
# 1246            1                          46                      46.0
# 1351            1                          70                      62.0
# 1358            2                         114                     104.0
# 1395            2                          46                      43.0
# 1402            1                          85                      80.0
# 1418            4                          66                      68.0
#
#       satisfaction
# 80               1
# 717              1
# 1061             1
# 71               0
# 305              0
# 424              0
# 429              0
# 624              0
# 671              0
# 805              1
# 868              0
# 919              0
# 961              0
# 1139             1
# 1192             1
# 1218             0
# 1222             0
# 1225             0
# 1246             0
# 1351             0
# 1358             0
# 1395             0
# 1402             0
# 1418             1
#
# [24 rows x 23 columns]

# %%
# drop outliers
train_df = train_df.drop(detect_outliers(train_df,["Age", "Flight_Distance", "Inflight_wifi_service", "Departure/Arrival_time_convenient", "Ease_of_Online_booking", "Gate_location", "Food_and_drink", "Online_boarding", "Seat_comfort", "Inflight_entertainment", "On-board_service", "Leg_room_service", "Checkin_service", "Inflight_service", "Cleanliness", "Departure_Delay_in_Minutes", "Arrival_Delay_in_Minutes"]),axis = 0).reset_index(drop = True)

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# The technique we've used in our code is called "Outlier Removal" or "Outlier Trimming." This involves identifying data points that are considered outliers based on certain criteria (such as being outside a certain range or threshold) and then simply removing those data points from the dataset.

# %% [markdown]
# ###3. Handling Categorical Values

# %%
ctgrs = ["Gender","Customer_Type","Type_of_Travel"]

for x in ctgrs:

    train_df[x] = [1 if each == train_df[x].unique()[0] else 0 for each in train_df[x]]

# %%
# Here, since our variable takes 3 different values (business, eco plus and eco), we converted the data into numerical data with a different method.
# (1=Business, 2=Eco plus, 3=Eco)
train_df.Class = [1 if x == "Business" else 2 if x == "Eco Plus" else 3 for x in train_df.Class]

# %%
#we can train our data with machine learning algorithms. For this, we divide our train data into dependent (target) and independent variables.
#And finally, we have to make our test data ready for processing as we train. We apply the same process to our test data as we did to our train data.
test_df.drop(["Unnamed: 0","id"],axis=1, inplace=True)

test_df.columns = [x.split()[0] + "_" + x.split()[1] + "_" + x.split()[2] + "_" + x.split()[3] if len(x.split()) > 3 else x for x in test_df.columns]
test_df.columns = [x.split()[0] + "_" + x.split()[1] + "_" + x.split()[2] if len(x.split()) > 2 else x for x in test_df.columns]
test_df.columns = [x.split()[0] + "_" + x.split()[1] if len(x.split()) > 1 else x for x in test_df.columns]

# %%
test_df.satisfaction = [1 if x == "satisfied" else 0 for x in test_df.satisfaction]

test_df.head()
# Out:
#    Gender      Customer_Type  Age   Type_of_Travel     Class  Flight_Distance  \
# 0  Female     Loyal Customer   52  Business travel       Eco              160
# 1  Female     Loyal Customer   36  Business travel  Business             2863
# 2    Male  disloyal Customer   20  Business travel       Eco              192
# 3    Male     Loyal Customer   44  Business travel  Business             3377
# 4  Female     Loyal Customer   49  Business travel       Eco             1182
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# 0                       3              4  ...                       5
# 1                       3              1  ...                       4
# 2                       2              4  ...                       2
# 3                       0              2  ...                       1
# 4                       4              3  ...                       2
#
#    On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival_Delay_in_Minutes  satisfaction
# 0                      44.0             1
# 1                       0.0             1
# 2                       0.0             0
# 3                       6.0             1
# 4                      20.0             1
#
# [5 rows x 23 columns]

# %%
ctgrs2 = ["Gender","Customer_Type","Type_of_Travel"]

for x in ctgrs2:

    test_df[x] = [1 if each == test_df[x].unique()[0] else 0 for each in test_df[x]]

test_df.Class = [1 if x == "Business" else 2 if x == "Eco Plus" else 3 for x in test_df.Class]

# %% [markdown]
# ###4. Train & Test Split and Normalization

# %%
x_train = train_df.drop(["satisfaction"],axis=1)
y_train = train_df.satisfaction.values


x_test = test_df.drop(["satisfaction"],axis=1)
y_test = test_df.satisfaction.values

# %%
x_train = (x_train - np.min(x_train)) / (np.max(x_train) - np.min(x_train))

x_test = (x_test - np.min(x_test)) / (np.max(x_test) - np.min(x_test))

# %% [markdown]
# # ***7. ML Model Implementation***

# %% [markdown]
# ###**Evaluation Metrics:**
#
# - **Accuracy:** Overall correctness of predictions.
#
# - **Precision:** Accuracy of positive predictions.
#
# - **Recall (Sensitivity):** Ability to identify actual positives.
#
# - **F1 Score:** Balance between precision and recall.
#
# - **ROC Curve and AUC:** Trade-off between true positive rate and false positive rate.
#
# These metrics collectively provide a comprehensive understanding of the model's performance in terms of classification accuracy, precision, and ability to correctly identify positive instances

# %% [markdown]
# # ML Model - 1
#
# Model : Logistic Regression
#
# Evaluation Metrices :
# - Accuracy ➡ 68.3%
# - Precision ➡ 80%
# - Recall ➡ 42.8%
# - F1 Score ➡ 55.8%

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, precision_score, recall_score, f1_score

lr = LogisticRegression()

lr.fit(x_train, y_train)

y_pred_lr = lr.predict(x_test)

y_proba_lr = lr.predict_proba(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred_lr))

print("Precision:", precision_score(y_test, y_pred_lr))

print("Recall:", recall_score(y_test, y_pred_lr))

print("F1-Score:", f1_score(y_test, y_pred_lr))

fpr_lr, tpr_lr, thresholds = roc_curve(y_test, y_proba_lr[:,1])

auc_lr = roc_auc_score(y_test, y_proba_lr[:,1])

plt.plot(fpr_lr, tpr_lr, color='red', label='Logistic Regression (AUC = %0.2f)' % auc_lr)

plt.xlabel('False Positive Rate')

plt.ylabel('True Positive Rate')

plt.title('ROC Curve - Logistic Regression')

plt.legend(loc='best')

plt.show()
# Out:
# Accuracy: 0.6833333333333333
# Precision: 0.8
# Recall: 0.42857142857142855
# F1-Score: 0.5581395348837209

# %% [markdown]
# # ML Model - 2
# Model : Decision Tree
#
# Evaluation Metrices :
# - Accuracy ➡ 53.6%
# - Precision ➡ 50.6%
# - Recall ➡ 27.1%
# - F1 Score ➡ 35.3%

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Instantiate the Decision Tree classifier
dt = DecisionTreeClassifier()

# Define the hyperparameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [9,10,11,12],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 5, 10]
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(dt, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Train the Decision Tree with the best hyperparameters
dt_best = DecisionTreeClassifier(**best_params)
dt_best.fit(x_train, y_train)

# Make predictions
y_pred_dt = dt_best.predict(x_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Precision:", precision_score(y_test, y_pred_dt))
print("Recall:", recall_score(y_test, y_pred_dt))
print("F1-Score:", f1_score(y_test, y_pred_dt))

# Calculate AUC and plot ROC Curve
y_proba_dt = dt_best.predict_proba(x_test)[:, 1]
fpr_dt, tpr_dt, thresholds = roc_curve(y_test, y_proba_dt)
auc_dt = roc_auc_score(y_test, y_proba_dt)

plt.plot(fpr_dt, tpr_dt, color='green', label='Decision Tree (AUC = %0.2f)' % auc_dt)
plt.plot(fpr_lr, tpr_lr, color='red', label='Logistic Regression (AUC = %0.2f)' % auc_lr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Decision Tree vs. Logistic Regression')
plt.legend(loc='best')
plt.show()
# Out:
# Accuracy: 0.5366666666666666
# Precision: 0.5066666666666667
# Recall: 0.2714285714285714
# F1-Score: 0.3534883720930232

# %%
from sklearn import tree
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(65,30))
tree.plot_tree(dt_best, fontsize=10, feature_names=x_train.columns, filled=True)
plt.show()

# %% [markdown]
# # ML Model - 3
# Model : KNN
#
# Evaluation Metrices :
# - Accuracy ➡ 63.6%
# - Precision ➡ 63.7%
# - Recall ➡ 51.4%
# - F1 Score ➡ 56.9%

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

knn = KNeighborsClassifier()

# Define the grid of hyperparameters to search
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11, 13, 15],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(knn, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best parameters:", grid_search.best_params_)

# Train the KNN model with the best hyperparameters
knn_best = KNeighborsClassifier(**grid_search.best_params_)
knn_best.fit(x_train, y_train)

# Evaluate the model on the test set
y_pred_knn = knn_best.predict(x_test)
y_proba_knn = knn_best.predict_proba(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred_knn))
print("Precision:", precision_score(y_test, y_pred_knn))
print("Recall:", recall_score(y_test, y_pred_knn))
print("F1-Score:", f1_score(y_test, y_pred_knn))

fpr_knn, tpr_knn, thresholds = roc_curve(y_test, y_proba_knn[:,1])
auc_knn = roc_auc_score(y_test, y_proba_knn[:,1])

plt.plot(fpr_knn, tpr_knn, color='red', label='KNN (AUC = %0.2f)' % auc_knn)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - KNN')
plt.legend(loc='best')
plt.show()
# Out:
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 11, 'weights': 'distance'}
# Accuracy: 0.6366666666666667
# Precision: 0.6371681415929203
# Recall: 0.5142857142857142
# F1-Score: 0.5691699604743082

# %% [markdown]
# # ML Model - 4
# Model : SVM (Support Vector Machine)
#
# Evaluation Metrices :
# - Accuracy ➡ 67%
# - Precision ➡ 78.8%
# - Recall ➡ 40%
# - F1 Score ➡ 53%

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC

# Define the SVM model
svm = SVC(probability=True)

# Define the hyperparameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto'],
}

# Define the StratifiedKFold cross-validation strategy
skf = StratifiedKFold(n_splits=5)

# Perform grid search with cross-validation
grid_search = GridSearchCV(svm, param_grid, cv=skf)
grid_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best parameters:", grid_search.best_params_)

# Train the SVM model with the best hyperparameters
svm_best = SVC(**grid_search.best_params_,probability=True)
svm_best.fit(x_train, y_train)

# Evaluate the model on the test set
y_pred_svm = svm_best.predict(x_test)
y_proba_svm = svm_best.predict_proba(x_test) # This line will now work

print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Precision:", precision_score(y_test, y_pred_svm))
print("Recall:", recall_score(y_test, y_pred_svm))
print("F1-Score:", f1_score(y_test, y_pred_svm))

fpr_svm, tpr_svm, thresholds = roc_curve(y_test, y_proba_svm[:,1])
auc_svm = roc_auc_score(y_test, y_proba_svm[:,1])

plt.plot(fpr_svm, tpr_svm, color='red', label='SVM (AUC = %0.2f)' % auc_svm)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - SVM')
plt.legend(loc='best')
plt.show()
# Out:
# Best parameters: {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy: 0.67
# Precision: 0.7887323943661971
# Recall: 0.4
# F1-Score: 0.5308056872037915

# %% [markdown]
# #Final Insights

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer :
# We chose Recall and F1 Score because Recal considers False Negative values too which are very crtical from business aspects and F1 Score is a balance of Precision and Recall so it gives a fair value useful for business insights.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer
# We chose Logistic Regression because its Accuracy, Precision, Recall and F1 Score are Best out of all models.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer : Logistic regression is a statistical method used for binary classification tasks, where the outcome variable (dependent variable) is categorical and has only two possible outcomes, typically labeled as 0 and 1. It's widely used in various fields such as healthcare, finance, marketing, and social sciences for predicting binary outcomes based on one or more predictor variables (independent variables).

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The implementation of machine learning models such as Logistic Regression, Decision Tree Classifier, Random Forest Classifier, and K-Nearest Neighbors (KNN) Classifier holds promise for predicting airline passenger satisfaction. Through thorough data preprocessing, including feature engineering and handling missing values, and employing hyperparameter tuning techniques like GridSearchCV, these models can effectively learn from the provided data and make accurate predictions. However, it's crucial to ensure proper evaluation metrics are employed to assess model performance accurately. By integrating these techniques into an ensemble model or deploying the best-performing individual model, airlines can enhance their understanding of passenger satisfaction factors and optimize service delivery.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
